# %% [markdown]
# <a href="https://colab.research.google.com/github/oyuka1112/oyuka1112/blob/main/pythontest1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
stocks = pd.read_csv("stocks1.csv")

# %%
#loading dataset and running some descriptive statistics
stocks.info()
stocks.describe()
stocks
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24732 entries, 0 to 24731
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Symbol                    24732 non-null  object
#  1   Date                      24732 non-null  object
#  2   Open                      24654 non-null  float64
#  3   High                      24693 non-null  float64
#  4   Low                       24674 non-null  float64
#  5   Close                     24732 non-null  float64
#  6   Volume                    24732 non-null  int64
#  7   Yesterday Volume          24732 non-null  int64
#  8   Tomorrows Percent Change  24732 non-null  float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 1.7+ MB
#       Symbol        Date  ...  Yesterday Volume  Tomorrows Percent Change
# 0       AAPL  11/11/2016  ...          57134541                 -2.508531
# ...

# %%
import matplotlib.pyplot as plt
#histogram
stocks.hist(bins =50, figsize = (20,15))
plt.show()

# %%
#scatter plots
stocks.plot(kind = 'scatter', x = 'Date', y = 'Volume', alpha = 0.2)

# %%
iris = pd.read_csv('Iris.data.csv')

# %%
iris.hist(bins= 30, figsize= (20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f15182c0e90>,
# ...
#       dtype=object)

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
iris = pd.read_csv('Iris.data.csv', header = None, names=names)
from pandas import DataFrame
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
iris = iris.drop('class', axis = 1)
pca = PCA(n_components=2).fit(iris)
df2 = pca.transform(iris)
kmeans = KMeans(n_clusters = 3).fit(df2)
centroids = kmeans.cluster_centers_
for i in range (0, df2.shape[0]):
  if kmeans.labels_[i] == 0:
    plt.scatter(df2[i,0], df2[i,1], c='green')
  elif kmeans.labels_[i]==1:
    plt.scatter(df2[i,0], df2[i,1], c='blue')
  elif kmeans.labels_[i] == 2:
    plt.scatter(df2[i,0], df2[i,1], c='yellow')
plt.scatter(centroids[:,0], centroids[:,1],c ='black', marker ='X')
plt.title('Clustering')
# Out:
# Text(0.5, 1.0, 'Clustering')
