# %% [markdown]
# <a href="https://colab.research.google.com/github/oyuka1112/oyuka1112/blob/main/numA_hw2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Problem 1
# f(x) = x2 -x -1 find x using bisection method and graph

def fun(x):
  y = x**2 -x -1
  return y

x = np.linspace(-3, 3, 100)
y = fun(x)
plt.plot(x, y, 'b')
plt.grid()
plt.axhline(y=0, color='r', linestyle='-')

# %%
#Problem 2
# fx = (np.exp(x)) -np.sin(x)
   #fx = x**2 - 4* np.sin(x) +(2.0 +np.sin(x))**2
def fun_1(x):
  first = (np.exp(x)) -np.sin(x)
  return first
def fun_2(x):
  second = x**2 - 4* np.sin(x) +(2.0 +np.sin(x))**2
  return second



x = np.arange(-5, 5, 0.001)

first = fun_1(x)
second = fun_2(x)

plt.plot(x, first, 'r')
plt.plot(x, second, 'b')
plt.grid()

# %%
# 3 use newtons method
# solve f(x) = (x-1)**2 *(np.sin(x))
import scipy.integrate as integrate
import scipy.special as special
from scipy import optimize

def fun(x):
  y = (x-1)**2 -(np.sin(x))
  return y
def derivfun(x):
  dy = 2*(x-1)+np.cos(x)
  return dy
x =  np.arange(-5, 7, 0.001)
y = fun(x)
dy = derivfun(x)


plt.plot(x, y, 'r')
plt.plot(x, dy, 'b')
plt.grid()
